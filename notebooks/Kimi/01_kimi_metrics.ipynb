# %%
from pathlib import Path
import os

ROOT = Path.cwd().parents[1]
os.chdir(ROOT)

print(os.getcwd())
# Out:
# e:\FAST 7th Sem\FYP\Data Filtering\snake-repairllama-baseline

# %%
from src.metrics import evaluate_file, print_report

qb = evaluate_file(
    inference_jsonl="results/quixbugs_kimi.jsonl",
    eval_jsonl="data/quixbugs_eval.jsonl",
)
print_report("QuixBugs — Kimi", qb)
# Out:
# ================================================================
#   BugsInPy — Kimi
#   Total bugs: 161    Bugs with plausibility data: 0
# ================================================================
#   Top-1  Exact     :    0 / 161 (  0.0%)
#   Top-1  AST       :    6 / 161 (  3.7%)
#   Top-1  Compile   :   26 / 161 ( 16.1%)
#
#   Top-3  Exact     :    0 / 161 (  0.0%)
#   Top-3  AST       :   12 / 161 (  7.5%)
#   Top-3  Compile   :   34 / 161 ( 21.1%)
#   Top-3  Buried    :    1 / 161 (  0.6%)
#
#   Top-10 Exact     :    0 / 161 (  0.0%)
#   Top-10 AST       :   15 / 161 (  9.3%)
#   Top-10 Compile   :   37 / 161 ( 23.0%)
#   Top-10 Buried    :    1 / 161 (  0.6%)
# ================================================================
# <unknown>:2: SyntaxWarning: invalid escape sequence '\.'
# <unknown>:2: SyntaxWarning: invalid escape sequence '\.'
# <unknown>:2: SyntaxWarning: invalid escape sequence '\d'
# <unknown>:2: SyntaxWarning: invalid escape sequence '\-'
# <unknown>:2: SyntaxWarning: invalid escape sequence '\.'
